# %%
# !rm -rf barnes_hut_nbody/

# !git clone https://github.com/salehgovahi/barnes_hut_nbody.git

# !cd barnes_hut_nbody/ && make clean
# !cd barnes_hut_nbody/ && make

# !cd barnes_hut_nbody/ && ./barnes_hut 100000 50
# Out:
# Cloning into 'barnes_hut_nbody'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15 (delta 0), reused 15 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 8.00 KiB | 8.00 MiB/s, done.
# rm -rf build ./barnes_hut
# nvcc -O3 -std=c++17 -Iinclude -arch=sm_70 -Xcompiler "-fopenmp" -c src/main.cpp -o build/main.o
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -O3 -std=c++17 -Iinclude -arch=sm_70 -Xcompiler "-fopenmp" -c src/wrappers_cuda.cu -o build/wrappers_cuda.o
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -O3 -std=c++17 -Iinclude -arch=sm_70 -c src/octree.cpp -o build/octree.o
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -O3 -std=c++17 -Iinclude -arch=sm_70 -Xcompiler "-fopenmp" -c src/barnes_hut_serial.cpp -o build/barnes_hut_serial.o
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -O3 -std=c++17 -Iinclude -arch=sm_70 -c src/barnes_hut_hybrid.cu -o build/barnes_hut_hybrid.o
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -O3 -std=c++17 -Iinclude -arch=sm_70 build/main.o build/wrappers_cuda.o build/octree.o build/barnes_hut_serial.o build/barnes_hut_hybrid.o -o ./barnes_hut -lgomp
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# +========================================================================+
# |        Barnes-Hut N-Body Simulation - Performance Comparison           |
# |                          Serial | Hybrid                               |
# +========================================================================+
#
# +------------------------------------------------------------------------+
# | System Information:                                                      |
# +------------------------------------------------------------------------+
# |  OpenMP:        Enabled (Version 201511)
# |  CPU Threads:   2 available
# |  CUDA:          Available
# +------------------------------------------------------------------------+
#
# Configuration: 100000 bodies, 50 steps
# Theta: 0.5, G: 6.674, dt: 0.01
#
# ===========================================================================
# Running SERIAL implementation...
#
#   [Serial] Completed 50 steps in 155.8925 seconds
#
# ===========================================================================
# Running HYBRID (CUDA + OpenMP) implementation...
#   [Hybrid] CPU(OpenMP Tasks) for Tree & GPU(CUDA) for Forces
#
#   [Hybrid] Completed 50 steps in 5.8714 seconds
#
# +========================================================================+
# |                         PERFORMANCE RESULTS                              |
# +========================================================================+
# |  Simulation: 100000 bodies,   50 steps                                 |
# +========================================================================+
# |  BASELINE (Serial):                                                     |
# |    Time:   155.8925 seconds                                      |
# |    Speedup: 1.00x (baseline)                                            |
# +========================================================================+
# |  HYBRID (CPU Tree + GPU Compute) Results:                               |
# |    Time:     5.8714 seconds                                      |
# |    Speedup:  26.55x                                              |
# +========================================================================+
#
# All tests completed!
